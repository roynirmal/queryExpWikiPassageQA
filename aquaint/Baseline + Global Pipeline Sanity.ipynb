# %%
import numpy as np
import pandas as pd
import csv
from tempfile import mkdtemp
import os.path as path
from scipy.sparse import csr_matrix, isspmatrix
import json
import io
import re
from time import gmtime, strftime
from datetime import datetime
import shlex, subprocess
import time
import glob
from krovetzstemmer import Stemmer
import string
from collections import Counter
import itertools
import random
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %% [markdown]
# ## Build Methods

# %%
def prepare_question_text(question_text):
    question_text = question_text.replace('?','') #remove ?
    question_text = question_text.replace("'",'')
    question_text = question_text.replace('"','')
    question_text = question_text.replace('-',' ')
    question_text = question_text.replace('(','')
    question_text = question_text.replace(')','')
    question_text = question_text.replace(',','')
    question_text = question_text.replace('.','')
    question_text = question_text.replace('&',' and ')
    question_text = question_text.replace(':','')
    question_text = question_text.replace('>','')#error in dataset
    question_text = question_text.replace('/',' ')

    return question_text

# %%
## Build a dataframe of query number and query for convenience 
queryDF = pd.DataFrame(columns=['queryNum', 'query'])
i = 0
with open('query.txt', 'w') as file_to_write:
    with open('Topic', 'r') as file_to_read:
        for line in file_to_read:
            if line.startswith("<num>"):
                queryNum = re.search(r'\d+', line)
            if line.startswith("<title>"):
                if(line.split("<title>",1)[1][:-1] == ""):
                    queryDF.loc[i] = [int(queryNum.group()), prepare_question_text(next(file_to_read)[:-1])]
                    i = i+1
                else:
                    queryDF.loc[i] = [int(queryNum.group()), prepare_question_text(line.split("<title> ",1)[1][:-1])]
                    i = i+1
    file_to_read.close()
file_to_write.close()
# Out:
#     queryNum                                query
# 0        301       International Organized Crime
# 1        302        Poliomyelitis and Post Polio
# 2        303       Hubble Telescope Achievements
# 3        304          Endangered Species Mammals
# 4        305             Most Dangerous Vehicles
# 5        306             African Civilian Deaths
# 6        307          New Hydroelectric Projects
# 7        308                   Implant Dentistry
# 8        309                       Rap and Crime
# 9        310        Radio Waves and Brain Cancer
# 10       311                Industrial Espionage
# 11       312                         Hydroponics
# 12       313          Magnetic Levitation Maglev
# 13       314                   Marine Vegetation
# 14       315        Unexplained Highway Accidents
# 15       316        Polygamy Polyandry Polygyny
# 16       317                   Unsolicited Faxes
# 17       318             Best Retirement Country
# 18       319                    New Fuel Sources
# 19       320          Undersea Fiber Optic Cable
# 20       321                Women in Parliaments
# 21       322             International Art Crime
# 22       323    Literary Journalistic Plagiarism
# 23       324          Argentine British Relations
# 24       325                     Cult Lifestyles
# 25       326                     Ferry Sinkings
# 26       327                      Modern Slavery
# 27       328                  Pope Beatifications
# 28       329               Mexican Air Pollution
# 29       330               Iran Iraq Cooperation
# ..       ...                                  ...
# 220      671              Salvation Army benefits
# 221      672               NRA membership profile
# 222      673        Soviet withdrawal Afghanistan
# 223      674                Greenpeace prosecuted
# 224      675           Olympics training swimming
# 225      676                    poppy cultivation
# 226      677                Leaning Tower of Pisa
# 227      678                 joint custody impact
# 228      679             opening adoption records
# 229      680            immigrants Spanish school
# 230      681                  wind power location
# 231      682             adult immigrants English
# 232      683               Czechoslovakia breakup
# 233      684                   part time benefits
# 234      685               Oscar winner selection
# 235      686             Argentina pegging dollar
# 236      687            Northern Ireland industry
# 237      688                    non US media bias
# 238      689                  family planning aid
# 239      690          college education advantage
# 240      691                clear cutting forests
# 241      692  prostate cancer detection treatment
# 242      693         newspapers electronic media
# 243      694                        compost pile
# 244      695          white collar crime sentence
# 245      696               safety plastic surgery
# 246      697               air traffic controller
# 247      698                literacy rates Africa
# 248      699                         term limits
# 249      700                      gasoline tax US
#
# [250 rows x 2 columns]

# %% [markdown]
# ## Make QUERY File and run Baseline Retrieval (in cmd)

# %%
with open('query.txt', 'w') as file_to_write:
    file_to_write.write("<parameter>\n")
    with open('Topic', 'r') as file_to_read:
#         table = str.maketrans('', '', string.punctuation)
#         sentences = [[w.translate(table) for w in x if not w in stop] for x in tokens]
        for line in file_to_read:
            
            if line.startswith("<num>"):
                file_to_write.write("<query>\n")
                queryNum = re.search(r'\d+', line)
                file_to_write.write('<number>'+ queryNum.group()+'</number>\n')
#                 print(queryNum.group())
            if line.startswith("<title>"):
                if(line.split("<title>",1)[1][:-1] == ""):
                   file_to_write.write('<text>'+  prepare_question_text(next(file_to_read)[:-1])  + '</text>\n')
                else:
                    
                    file_to_write.write('<text>'+ line.split("<title>",1)[1][:-1] + '</text>\n')
                file_to_write.write("</query>\n")
    # if it starts with <num>, extract the qnum
            # if it starts with <title>, extract the title
            # break from while loop
    file_to_read.close()
    file_to_write.write("</parameter>\n")
file_to_write.close()
        # write <query>
        # write the num
        # write the text
        # write </query>

# %% [markdown]
# ## GLOBAL EMBEDDING

# %%
words = pd.read_table(r'C:\Users\nroy0\Downloads\Thesis\glove.6B\glove.6B.50d.txt', sep=" ", index_col=0, header=None, quoting=csv.QUOTE_NONE)
words100 = pd.read_table(r'C:\Users\nroy0\Downloads\Thesis\glove.6B\glove.6B.100d.txt', sep=" ", index_col=0, header=None, quoting=csv.QUOTE_NONE)
words200 = pd.read_table(r'C:\Users\nroy0\Downloads\Thesis\glove.6B\glove.6B.200d.txt', sep=" ", index_col=0, header=None, quoting=csv.QUOTE_NONE)
words300 = pd.read_table(r'C:\Users\nroy0\Downloads\Thesis\glove.6B\glove.6B.300d.txt', sep=" ", index_col=0, header=None, quoting=csv.QUOTE_NONE)

# %%
stop = json.load(open(r'C:\Users\nroy0\Downloads\Thesis\glove.6B\SMARTstop.json'))

# %%
def vec(w):
    return words.loc[w].as_matrix()

# %%
wordList = words.index.values
word100List = words100.index.values
word200ListS = words200.index.values
word300ListS = words300.index.values
U = words100.as_matrix()

# %%
def candidateTerms( question,k):
    filtered_text = removeStopWords(question)
    q = binaryEncoding( filtered_text)
    tmp = np.matmul(U.T,q)
    candidate = np.matmul(U,tmp)
    index = np.argsort(-candidate)[:k]
    weights = -np.sort(-candidate)[:k]
    normW = normalise(weights)
    expansionTerms = np.asarray(word100List)[index]
    pqPlus = dict(zip(expansionTerms,normW))
    return pqPlus

# %%
def removeStopWords(questionText):
    return [w.lower() for w in questionText.split()  if not w in stop]

# %%
def binaryEncoding(qText):
    questionList = qText
    binaryEncoded =np.array([ 1 if i in questionList else 0 for i in word100List])
    return binaryEncoded

# %%
def normalise(weights):
    sumW = np.sum(weights)
    normW = weights/sumW
    return normW

# %%
def queryFormat(lamda, question_text, arr):
    expansionTerms = convertExpansionTerms(question_text, arr)
    filtered_text = removeStopWords(question_text)
    finalQueryText = '<text>#weight( ' + str(lamda)+' #combine ( '+ ' '.join(word for word in filtered_text) + " ) " + str(1 - lamda) + " #weight( " + expansionTerms + ") )</text>"
    return finalQueryText

# %%
def convertExpansionTerms(question_text, arr):
    onlyUniqueWords = [i for i in list(arr) if i.isalpha()]
#     onlyUniqueWords = np.setdiff1d(onlyWords, question_text.split())
    weightO = normalise([arr[x] for x in onlyUniqueWords])
    testStr = ""
    for item in range(len(onlyUniqueWords)):
        testStr = testStr + str(round(weightO[item],4))+" "+str(onlyUniqueWords[item]) + " "
    return testStr

# %%
arr = candidateTerms('International Organized Crime', 50)
queryFormat(0.5, 'International Organized Crime', arr)
# Out:
# '<text>#weight( 0.5 #combine ( international organized crime ) 0.5 #weight( 0.0232 international 0.0223 crime 0.0217 organizations 0.0215 groups 0.0214 activities 0.0212 organization 0.0211 criminal 0.021 countries 0.0207 terrorism 0.0207 crimes 0.0206 economic 0.0206 political 0.0205 government 0.0203 trafficking 0.0203 terrorist 0.0203 military 0.0201 security 0.02 corruption 0.02 rights 0.02 cooperation 0.0199 national 0.0199 anti 0.0198 group 0.0198 department 0.0198 law 0.0198 police 0.0197 public 0.0197 violence 0.0197 world 0.0197 enforcement 0.0196 nations 0.0196 agencies 0.0196 islamic 0.0195 regional 0.0194 organized 0.0193 social 0.0193 efforts 0.0193 officials 0.0192 laws 0.0192 authorities 0.0192 drug 0.0192 investigation 0.0191 european 0.0191 commission 0.0191 global 0.019 country 0.019 financial 0.019 action 0.019 china 0.019 civil ) )</text>'

# %%
def originalGlobal(expansion_terms, lamda, X_train, mode, cv):
    if mode == 'train':
        queryFile = 'C:/Users/nroy0/Downloads/Thesis/aquaint/Vol45/Global100Queries/train/' + str(cv)+'/query_global_'+str(lamda) + '_' + str(expansion_terms) +'.txt'
    elif mode == 'test':
        queryFile = 'C:/Users/nroy0/Downloads/Thesis/aquaint/Vol45/Global100Queries/test/query_global_'+str(lamda) + '_' + str(expansion_terms) + '_' + str(cv) +'.txt'

     
    with io.open(queryFile, 'w',  encoding="utf-8") as file_to_write:
        file_to_write.write("<parameter>\n")
        for i in range(len(X_train)):
#             print(i)
            file_to_write.write("<query>\n")
            file_to_write.write('<number>'+ str(X_train['queryNum'][i])+'</number>\n')
            question_text =prepare_question_text(X_train['query'][i])
            arr = candidateTerms(question_text , expansion_terms)
            finalQueryText = queryFormat(lamda, question_text, arr)
            file_to_write.write(finalQueryText + '\n')
            with open(r'C:\Users\nroy0\Downloads\Thesis\trec_eval.9.0\original\output\baselineQL_[1000].indri') as indrifile:
                for output in indrifile:
                    if output[:3] == str(X_train['queryNum'][i]):
                        doc = re.search(r'Q0 (.*?) ', output).group(1)
                        file_to_write.write('<workingSetDocno>'+doc+ '</workingSetDocno>\n')
            indrifile.close()
            file_to_write.write("</query>\n")

#         file_to_read.close()
        file_to_write.write("</parameter>\n")
    file_to_write.close()
    return queryFile

# %% [markdown]
# ## Cross Validation

# %%
kf = KFold( n_splits = 5, shuffle = True)
cv = 0
queryTestindex = {}
for train_index,test_index in kf.split(queryDF):
    cv = cv+1
    X_train, X_test = queryDF.loc[train_index].reset_index(), queryDF.loc[test_index].reset_index()
    queryTestindex[cv]= test_index
    for expansion_terms in [ 50, 100, 200]:
        for lamda in [  0.3, 0.45, 0.6, 0.75]: 
            startTime = time.time()
            queryTrainFile = originalGlobal(expansion_terms, lamda, X_train, 'train', cv)
            
#             queryTestFile = originalGlobal(expansion_terms, lamda, X_test, 'test', cv)
            endTime = time.time()
            t_sec = round(endTime - startTime)
            (t_min, t_sec) = divmod(t_sec,60)
            print('Query File for Lamda {} and expansion terms {} created, time taken {} minutes and {} seconds'.format(lamda, expansion_terms, t_min, t_sec))
            for mu in [ 500, 750, 1000, 1500, 2000 ]:
                startTime = time.time()
                outputFile = str(cv)+'/QL_['+str(mu)+'_'+str(lamda)+'_'+str(expansion_terms)+'].indri'
                command_input= r'"C:\Users\nroy0\Downloads\Thesis\Lemur\bin\IndriRunQuery.exe" '+str(queryTrainFile)+' -index=Vol45/index -count=1000 -trecFormat=true -queryOffset=-1 -rule=method:dirichlet,mu:' +str(mu)+' -stemmer.name=krovetz > C:/Users/nroy0/Downloads/Thesis/trec_eval.9.0/original/global100/'+str(outputFile) 
                args = shlex.split(command_input)
                p = subprocess.run(args, stderr=subprocess.STDOUT,shell=True)
                endTime = time.time()
                t_sec = round(endTime - startTime)
                (t_min, t_sec) = divmod(t_sec,60)
                print("Mu {} complete, time take {} min and {} sec".format(mu, t_min, t_sec ))
        print("Cross Validation {} Complete".format(cv))
# Out:
# Query File for Lamda 0.3 and expansion terms 50 created, time taken 8 minutes and 49 seconds
# Mu 500 complete, time take 0 min and 25 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.45 and expansion terms 50 created, time taken 8 minutes and 45 seconds
# Mu 500 complete, time take 0 min and 23 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.6 and expansion terms 50 created, time taken 8 minutes and 31 seconds
# Mu 500 complete, time take 0 min and 22 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 21 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 21 sec
# Query File for Lamda 0.75 and expansion terms 50 created, time taken 8 minutes and 31 seconds
# Mu 500 complete, time take 0 min and 22 sec
# Mu 750 complete, time take 0 min and 22 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 22 sec
# Mu 2000 complete, time take 0 min and 22 sec
# Cross Validation 1 Complete
# Query File for Lamda 0.3 and expansion terms 100 created, time taken 8 minutes and 24 seconds
# Mu 500 complete, time take 0 min and 47 sec
# Mu 750 complete, time take 0 min and 43 sec
# Mu 1000 complete, time take 0 min and 43 sec
# Mu 1500 complete, time take 0 min and 43 sec
# Mu 2000 complete, time take 0 min and 48 sec
# Query File for Lamda 0.45 and expansion terms 100 created, time taken 9 minutes and 21 seconds
# Mu 500 complete, time take 0 min and 42 sec
# Mu 750 complete, time take 0 min and 43 sec
# Mu 1000 complete, time take 0 min and 43 sec
# Mu 1500 complete, time take 0 min and 42 sec
# Mu 2000 complete, time take 0 min and 42 sec
# Query File for Lamda 0.6 and expansion terms 100 created, time taken 8 minutes and 43 seconds
# Mu 500 complete, time take 0 min and 43 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 39 sec
# Mu 1500 complete, time take 0 min and 42 sec
# Mu 2000 complete, time take 0 min and 40 sec
# Query File for Lamda 0.75 and expansion terms 100 created, time taken 8 minutes and 56 seconds
# Mu 500 complete, time take 0 min and 43 sec
# Mu 750 complete, time take 0 min and 42 sec
# Mu 1000 complete, time take 0 min and 43 sec
# Mu 1500 complete, time take 0 min and 43 sec
# Mu 2000 complete, time take 0 min and 44 sec
# Cross Validation 1 Complete
# Query File for Lamda 0.3 and expansion terms 200 created, time taken 9 minutes and 11 seconds
# Mu 500 complete, time take 1 min and 27 sec
# Mu 750 complete, time take 1 min and 26 sec
# Mu 1000 complete, time take 1 min and 27 sec
# Mu 1500 complete, time take 1 min and 26 sec
# Mu 2000 complete, time take 1 min and 26 sec
# Query File for Lamda 0.45 and expansion terms 200 created, time taken 9 minutes and 12 seconds
# Mu 500 complete, time take 1 min and 26 sec
# Mu 750 complete, time take 1 min and 26 sec
# Mu 1000 complete, time take 1 min and 26 sec
# Mu 1500 complete, time take 1 min and 26 sec
# Mu 2000 complete, time take 1 min and 28 sec
# Query File for Lamda 0.6 and expansion terms 200 created, time taken 9 minutes and 9 seconds
# Mu 500 complete, time take 1 min and 27 sec
# Mu 750 complete, time take 1 min and 26 sec
# Mu 1000 complete, time take 1 min and 27 sec
# Mu 1500 complete, time take 1 min and 27 sec
# Mu 2000 complete, time take 1 min and 27 sec
# Query File for Lamda 0.75 and expansion terms 200 created, time taken 9 minutes and 8 seconds
# Mu 500 complete, time take 1 min and 28 sec
# Mu 750 complete, time take 1 min and 27 sec
# Mu 1000 complete, time take 1 min and 28 sec
# Mu 1500 complete, time take 1 min and 28 sec
# Mu 2000 complete, time take 1 min and 28 sec
# Cross Validation 1 Complete
# Query File for Lamda 0.3 and expansion terms 50 created, time taken 9 minutes and 8 seconds
# Mu 500 complete, time take 0 min and 26 sec
# Mu 750 complete, time take 0 min and 25 sec
# Mu 1000 complete, time take 0 min and 25 sec
# Mu 1500 complete, time take 0 min and 27 sec
# Mu 2000 complete, time take 0 min and 26 sec
# Query File for Lamda 0.45 and expansion terms 50 created, time taken 9 minutes and 2 seconds
# Mu 500 complete, time take 0 min and 25 sec
# Mu 750 complete, time take 0 min and 25 sec
# Mu 1000 complete, time take 0 min and 25 sec
# Mu 1500 complete, time take 0 min and 25 sec
# Mu 2000 complete, time take 0 min and 25 sec
# Query File for Lamda 0.6 and expansion terms 50 created, time taken 9 minutes and 5 seconds
# Mu 500 complete, time take 0 min and 25 sec
# Mu 750 complete, time take 0 min and 25 sec
# Mu 1000 complete, time take 0 min and 25 sec
# Mu 1500 complete, time take 0 min and 25 sec
# Mu 2000 complete, time take 0 min and 25 sec
# Query File for Lamda 0.75 and expansion terms 50 created, time taken 8 minutes and 55 seconds
# Mu 500 complete, time take 0 min and 24 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 24 sec
# Mu 1500 complete, time take 0 min and 24 sec
# Mu 2000 complete, time take 0 min and 24 sec
# Cross Validation 2 Complete
# Query File for Lamda 0.3 and expansion terms 100 created, time taken 8 minutes and 31 seconds
# Mu 500 complete, time take 0 min and 44 sec
# Mu 750 complete, time take 0 min and 43 sec
# Mu 1000 complete, time take 0 min and 42 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 42 sec
# Query File for Lamda 0.45 and expansion terms 100 created, time taken 8 minutes and 31 seconds
# Mu 500 complete, time take 0 min and 43 sec
# Mu 750 complete, time take 0 min and 43 sec
# Mu 1000 complete, time take 0 min and 42 sec
# Mu 1500 complete, time take 0 min and 42 sec
# Mu 2000 complete, time take 0 min and 42 sec
# Query File for Lamda 0.6 and expansion terms 100 created, time taken 8 minutes and 31 seconds
# Mu 500 complete, time take 0 min and 42 sec
# Mu 750 complete, time take 0 min and 44 sec
# Mu 1000 complete, time take 0 min and 45 sec
# Mu 1500 complete, time take 0 min and 42 sec
# Mu 2000 complete, time take 0 min and 40 sec
# Query File for Lamda 0.75 and expansion terms 100 created, time taken 8 minutes and 6 seconds
# Mu 500 complete, time take 0 min and 39 sec
# Mu 750 complete, time take 0 min and 44 sec
# Mu 1000 complete, time take 0 min and 45 sec
# Mu 1500 complete, time take 0 min and 46 sec
# Mu 2000 complete, time take 0 min and 43 sec
# Cross Validation 2 Complete
# Query File for Lamda 0.3 and expansion terms 200 created, time taken 8 minutes and 41 seconds
# Mu 500 complete, time take 1 min and 25 sec
# Mu 750 complete, time take 1 min and 21 sec
# Mu 1000 complete, time take 1 min and 24 sec
# Mu 1500 complete, time take 1 min and 21 sec
# Mu 2000 complete, time take 1 min and 24 sec
# Query File for Lamda 0.45 and expansion terms 200 created, time taken 8 minutes and 8 seconds
# Mu 500 complete, time take 1 min and 20 sec
# Mu 750 complete, time take 1 min and 19 sec
# Mu 1000 complete, time take 1 min and 20 sec
# Mu 1500 complete, time take 1 min and 20 sec
# Mu 2000 complete, time take 1 min and 20 sec
# Query File for Lamda 0.6 and expansion terms 200 created, time taken 7 minutes and 56 seconds
# Mu 500 complete, time take 1 min and 20 sec
# Mu 750 complete, time take 1 min and 21 sec
# Mu 1000 complete, time take 1 min and 26 sec
# Mu 1500 complete, time take 1 min and 21 sec
# Mu 2000 complete, time take 1 min and 22 sec
# Query File for Lamda 0.75 and expansion terms 200 created, time taken 8 minutes and 38 seconds
# Mu 500 complete, time take 1 min and 25 sec
# Mu 750 complete, time take 1 min and 28 sec
# Mu 1000 complete, time take 1 min and 26 sec
# Mu 1500 complete, time take 1 min and 27 sec
# Mu 2000 complete, time take 1 min and 25 sec
# Cross Validation 2 Complete
# Query File for Lamda 0.3 and expansion terms 50 created, time taken 8 minutes and 28 seconds
# Mu 500 complete, time take 0 min and 23 sec
# Mu 750 complete, time take 0 min and 22 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 22 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.45 and expansion terms 50 created, time taken 8 minutes and 35 seconds
# Mu 500 complete, time take 0 min and 24 sec
# Mu 750 complete, time take 0 min and 24 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 22 sec
# Mu 2000 complete, time take 0 min and 22 sec
# Query File for Lamda 0.6 and expansion terms 50 created, time taken 8 minutes and 28 seconds
# Mu 500 complete, time take 0 min and 23 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 22 sec
# Mu 1500 complete, time take 0 min and 22 sec
# Mu 2000 complete, time take 0 min and 22 sec
# Query File for Lamda 0.75 and expansion terms 50 created, time taken 8 minutes and 30 seconds
# Mu 500 complete, time take 0 min and 22 sec
# Mu 750 complete, time take 0 min and 22 sec
# Mu 1000 complete, time take 0 min and 22 sec
# Mu 1500 complete, time take 0 min and 21 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Cross Validation 3 Complete
# Query File for Lamda 0.3 and expansion terms 100 created, time taken 8 minutes and 15 seconds
# Mu 500 complete, time take 0 min and 42 sec
# Mu 750 complete, time take 0 min and 40 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 42 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Query File for Lamda 0.45 and expansion terms 100 created, time taken 8 minutes and 16 seconds
# Mu 500 complete, time take 0 min and 42 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 43 sec
# Query File for Lamda 0.6 and expansion terms 100 created, time taken 8 minutes and 26 seconds
# Mu 500 complete, time take 0 min and 41 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 40 sec
# Mu 1500 complete, time take 0 min and 40 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Query File for Lamda 0.75 and expansion terms 100 created, time taken 8 minutes and 12 seconds
# Mu 500 complete, time take 0 min and 41 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 40 sec
# Mu 1500 complete, time take 0 min and 40 sec
# Mu 2000 complete, time take 0 min and 40 sec
# Cross Validation 3 Complete
# Query File for Lamda 0.3 and expansion terms 200 created, time taken 8 minutes and 11 seconds
# Mu 500 complete, time take 1 min and 22 sec
# Mu 750 complete, time take 1 min and 21 sec
# Mu 1000 complete, time take 1 min and 21 sec
# Mu 1500 complete, time take 1 min and 21 sec
# Mu 2000 complete, time take 1 min and 21 sec
# Query File for Lamda 0.45 and expansion terms 200 created, time taken 8 minutes and 11 seconds
# Mu 500 complete, time take 1 min and 22 sec
# Mu 750 complete, time take 1 min and 21 sec
# Mu 1000 complete, time take 1 min and 22 sec
# Mu 1500 complete, time take 1 min and 22 sec
# Mu 2000 complete, time take 1 min and 21 sec
# Query File for Lamda 0.6 and expansion terms 200 created, time taken 8 minutes and 10 seconds
# Mu 500 complete, time take 1 min and 22 sec
# Mu 750 complete, time take 1 min and 26 sec
# Mu 1000 complete, time take 1 min and 34 sec
# Mu 1500 complete, time take 1 min and 30 sec
# Mu 2000 complete, time take 1 min and 30 sec
# Query File for Lamda 0.75 and expansion terms 200 created, time taken 8 minutes and 54 seconds
# Mu 500 complete, time take 1 min and 30 sec
# Mu 750 complete, time take 1 min and 30 sec
# Mu 1000 complete, time take 1 min and 30 sec
# Mu 1500 complete, time take 1 min and 30 sec
# Mu 2000 complete, time take 1 min and 30 sec
# Cross Validation 3 Complete
# Query File for Lamda 0.3 and expansion terms 50 created, time taken 8 minutes and 51 seconds
# Mu 500 complete, time take 0 min and 22 sec
# Mu 750 complete, time take 0 min and 22 sec
# Mu 1000 complete, time take 0 min and 22 sec
# Mu 1500 complete, time take 0 min and 21 sec
# Mu 2000 complete, time take 0 min and 21 sec
# Query File for Lamda 0.45 and expansion terms 50 created, time taken 8 minutes and 39 seconds
# Mu 500 complete, time take 0 min and 24 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.6 and expansion terms 50 created, time taken 8 minutes and 48 seconds
# Mu 500 complete, time take 0 min and 24 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.75 and expansion terms 50 created, time taken 8 minutes and 46 seconds
# Mu 500 complete, time take 0 min and 26 sec
# Mu 750 complete, time take 0 min and 24 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Cross Validation 4 Complete
# Query File for Lamda 0.3 and expansion terms 100 created, time taken 8 minutes and 31 seconds
# Mu 500 complete, time take 0 min and 42 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Query File for Lamda 0.45 and expansion terms 100 created, time taken 8 minutes and 29 seconds
# Mu 500 complete, time take 0 min and 42 sec
# Mu 750 complete, time take 0 min and 40 sec
# Mu 1000 complete, time take 0 min and 40 sec
# Mu 1500 complete, time take 0 min and 40 sec
# Mu 2000 complete, time take 0 min and 40 sec
# Query File for Lamda 0.6 and expansion terms 100 created, time taken 8 minutes and 18 seconds
# Mu 500 complete, time take 0 min and 40 sec
# Mu 750 complete, time take 0 min and 42 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Query File for Lamda 0.75 and expansion terms 100 created, time taken 8 minutes and 28 seconds
# Mu 500 complete, time take 0 min and 41 sec
# Mu 750 complete, time take 0 min and 40 sec
# Mu 1000 complete, time take 0 min and 40 sec
# Mu 1500 complete, time take 0 min and 40 sec
# Mu 2000 complete, time take 0 min and 40 sec
# Cross Validation 4 Complete
# Query File for Lamda 0.3 and expansion terms 200 created, time taken 8 minutes and 17 seconds
# Mu 500 complete, time take 1 min and 19 sec
# Mu 750 complete, time take 1 min and 19 sec
# Mu 1000 complete, time take 1 min and 19 sec
# Mu 1500 complete, time take 1 min and 19 sec
# Mu 2000 complete, time take 1 min and 19 sec
# Query File for Lamda 0.45 and expansion terms 200 created, time taken 8 minutes and 17 seconds
# Mu 500 complete, time take 1 min and 19 sec
# Mu 750 complete, time take 1 min and 19 sec
# Mu 1000 complete, time take 1 min and 19 sec
# Mu 1500 complete, time take 1 min and 19 sec
# Mu 2000 complete, time take 1 min and 19 sec
# Query File for Lamda 0.6 and expansion terms 200 created, time taken 8 minutes and 17 seconds
# Mu 500 complete, time take 1 min and 19 sec
# Mu 750 complete, time take 1 min and 19 sec
# Mu 1000 complete, time take 1 min and 19 sec
# Mu 1500 complete, time take 1 min and 19 sec
# Mu 2000 complete, time take 1 min and 19 sec
# Query File for Lamda 0.75 and expansion terms 200 created, time taken 8 minutes and 17 seconds
# Mu 500 complete, time take 1 min and 21 sec
# Mu 750 complete, time take 1 min and 21 sec
# Mu 1000 complete, time take 1 min and 19 sec
# Mu 1500 complete, time take 1 min and 19 sec
# Mu 2000 complete, time take 1 min and 19 sec
# Cross Validation 4 Complete
# Query File for Lamda 0.3 and expansion terms 50 created, time taken 8 minutes and 15 seconds
# Mu 500 complete, time take 0 min and 23 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.45 and expansion terms 50 created, time taken 8 minutes and 15 seconds
# Mu 500 complete, time take 0 min and 23 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.6 and expansion terms 50 created, time taken 8 minutes and 14 seconds
# Mu 500 complete, time take 0 min and 23 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Query File for Lamda 0.75 and expansion terms 50 created, time taken 8 minutes and 14 seconds
# Mu 500 complete, time take 0 min and 23 sec
# Mu 750 complete, time take 0 min and 23 sec
# Mu 1000 complete, time take 0 min and 23 sec
# Mu 1500 complete, time take 0 min and 23 sec
# Mu 2000 complete, time take 0 min and 23 sec
# Cross Validation 5 Complete
# Query File for Lamda 0.3 and expansion terms 100 created, time taken 8 minutes and 16 seconds
# Mu 500 complete, time take 0 min and 41 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Query File for Lamda 0.45 and expansion terms 100 created, time taken 8 minutes and 14 seconds
# Mu 500 complete, time take 0 min and 41 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Query File for Lamda 0.6 and expansion terms 100 created, time taken 8 minutes and 16 seconds
# Mu 500 complete, time take 0 min and 41 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Query File for Lamda 0.75 and expansion terms 100 created, time taken 8 minutes and 14 seconds
# Mu 500 complete, time take 0 min and 41 sec
# Mu 750 complete, time take 0 min and 41 sec
# Mu 1000 complete, time take 0 min and 41 sec
# Mu 1500 complete, time take 0 min and 41 sec
# Mu 2000 complete, time take 0 min and 41 sec
# Cross Validation 5 Complete
# Query File for Lamda 0.3 and expansion terms 200 created, time taken 8 minutes and 15 seconds
# Mu 500 complete, time take 1 min and 21 sec
# Mu 750 complete, time take 1 min and 20 sec
# Mu 1000 complete, time take 1 min and 20 sec
# Mu 1500 complete, time take 1 min and 26 sec
# Mu 2000 complete, time take 1 min and 21 sec
# Query File for Lamda 0.45 and expansion terms 200 created, time taken 8 minutes and 13 seconds
# Mu 500 complete, time take 1 min and 21 sec
# Mu 750 complete, time take 1 min and 20 sec
# Mu 1000 complete, time take 1 min and 20 sec
# Mu 1500 complete, time take 1 min and 20 sec
# Mu 2000 complete, time take 1 min and 20 sec
# Query File for Lamda 0.6 and expansion terms 200 created, time taken 8 minutes and 14 seconds
# Mu 500 complete, time take 1 min and 20 sec
# Mu 750 complete, time take 1 min and 20 sec
# Mu 1000 complete, time take 1 min and 20 sec
# Mu 1500 complete, time take 1 min and 20 sec
# Mu 2000 complete, time take 1 min and 20 sec
# Query File for Lamda 0.75 and expansion terms 200 created, time taken 8 minutes and 13 seconds
# Mu 500 complete, time take 1 min and 20 sec
# Mu 750 complete, time take 1 min and 20 sec
# Mu 1000 complete, time take 1 min and 21 sec
# Mu 1500 complete, time take 1 min and 20 sec
# Mu 2000 complete, time take 1 min and 20 sec
# Cross Validation 5 Complete

# %%
path = r'C:\Users\nroy0\Downloads\Thesis\trec_eval.9.0\original\global100\5'
filenames = glob.glob(path + "/*.csv")
dfs = []
count = 0
for filename in filenames:
    match = re.search(r'\w\w\_\[\d\.?\d*\_\d\.?\d*\_\d+\]', filename)
    count = count + 1
#     print(count)
    colname = match.group()
    df = pd.read_table(filename,sep='\t', index_col=None, header=None, usecols=[2], skiprows =1, names =  [colname] , quoting=csv.QUOTE_NONE)
    dfs.append(df)
resultQL = pd.concat(dfs, axis=1, ignore_index = False)

resultQL['index']=[ 'num_q',
'num_ret',
'num_rel',
'num_rel_ret',
'map',
'gm_map',
'Rprec',
'bpref',
'recip_rank',
'iprec_at_recall_0.00',
'iprec_at_recall_0.10',
'iprec_at_recall_0.20',
'iprec_at_recall_0.30',
'iprec_at_recall_0.40',
'iprec_at_recall_0.50',
'iprec_at_recall_0.60',
'iprec_at_recall_0.70',
'iprec_at_recall_0.80',
'iprec_at_recall_0.90',
'iprec_at_recall_1.00',
'P_5',
'P_10',
'P_15',
'P_20',
'P_30',
'P_100',
'P_200',
'P_500',
'P_1000',
'recall_5',
'recall_10',
'recall_15',
'recall_20',
'recall_30',
'recall_100',
'recall_200',
'recall_500',
'recall_1000',
'infAP',
'gm_bpref',
'Rprec_mult_0.20',
'Rprec_mult_0.40',
'Rprec_mult_0.60',
'Rprec_mult_0.80',
'Rprec_mult_1.00',
'Rprec_mult_1.20',
'Rprec_mult_1.40',
'Rprec_mult_1.60',
'Rprec_mult_1.80',
'Rprec_mult_2.00',
'utility',
'11pt_avg',
'binG',
'G',
'ndcg',
'ndcg_rel',
'Rndcg',
'ndcg_cut_5',
'ndcg_cut_10',
'ndcg_cut_15',
'ndcg_cut_20',
'ndcg_cut_30',
'ndcg_cut_100',
'ndcg_cut_200',
'ndcg_cut_500',
'ndcg_cut_1000',
'map_cut_5',
'map_cut_10',
'map_cut_15',
'map_cut_20',
'map_cut_30',
'map_cut_100',
'map_cut_200',
'map_cut_500',
'map_cut_1000',
'relative_P_5',
'relative_P_10',
'relative_P_15',
'relative_P_20',
'relative_P_30',
'relative_P_100',
'relative_P_200',
'relative_P_500',
'relative_P_1000',
'success_1',
'success_5',
'success_10',
'set_P',
'set_relative_P',
'set_recall',
'set_map',
'set_F',
'num_nonrel_judged_ret']
resultQL = resultQL.set_index('index')
resultQL
# Out:
#                        QL_[1000_0.3_100]  QL_[1000_0.3_200]  QL_[1000_0.3_50]  \
# index
# num_q                           199.0000           199.0000          199.0000
# num_ret                      192035.0000        192035.0000       192035.0000
# num_rel                       13369.0000         13369.0000        13369.0000
# num_rel_ret                    7909.0000          7909.0000         7909.0000
# map                               0.2423             0.2472            0.2329
# gm_map                            0.1416             0.1443            0.1339
# Rprec                             0.2866             0.2915            0.2793
# bpref                             0.2530             0.2559            0.2454
# recip_rank                        0.6962             0.6916            0.6435
# iprec_at_recall_0.00              0.7318             0.7324            0.6923
# iprec_at_recall_0.10              0.5099             0.5211            0.4857
# iprec_at_recall_0.20              0.3999             0.4170            0.3765
# iprec_at_recall_0.30              0.3199             0.3338            0.3043
# iprec_at_recall_0.40              0.2599             0.2638            0.2511
# iprec_at_recall_0.50              0.2183             0.2226            0.2123
# iprec_at_recall_0.60              0.1750             0.1748            0.1725
# iprec_at_recall_0.70              0.1333             0.1351            0.1324
# iprec_at_recall_0.80              0.0866             0.0896            0.0863
# iprec_at_recall_0.90              0.0562             0.0566            0.0574
# iprec_at_recall_1.00              0.0263             0.0258            0.0242
# P_5                               0.4553             0.4804            0.4291
# P_10                              0.4010             0.4256            0.3794
# P_15                              0.3709             0.3883            0.3508
# P_20                              0.3417             0.3563            0.3317
# P_30                              0.3070             0.3119            0.2926
# P_100                             0.1810             0.1829            0.1771
# P_200                             0.1224             0.1233            0.1208
# P_500                             0.0669             0.0665            0.0665
# P_1000                            0.0397             0.0397            0.0397
# recall_5                          0.0838             0.0877            0.0820
# ...                                  ...                ...               ...
# ndcg_cut_200                      0.4356             0.4411            0.4240
# ndcg_cut_500                      0.4867             0.4883            0.4763
# ndcg_cut_1000                     0.5166             0.5197            0.5070
# map_cut_5                         0.0696             0.0713            0.0663
# map_cut_10                        0.1014             0.1056            0.0944
# map_cut_15                        0.1232             0.1279            0.1149
# map_cut_20                        0.1368             0.1428            0.1302
# map_cut_30                        0.1585             0.1628            0.1493
# map_cut_100                       0.2066             0.2119            0.1967
# map_cut_200                       0.2242             0.2292            0.2143
# map_cut_500                       0.2371             0.2418            0.2275
# map_cut_1000                      0.2423             0.2472            0.2329
# relative_P_5                      0.4565             0.4819            0.4304
# relative_P_10                     0.4163             0.4408            0.3933
# relative_P_15                     0.4022             0.4192            0.3801
# relative_P_20                     0.3900             0.4047            0.3798
# relative_P_30                     0.3899             0.3953            0.3725
# relative_P_100                    0.4323             0.4355            0.4240
# relative_P_200                    0.5027             0.5097            0.4994
# relative_P_500                    0.6192             0.6151            0.6180
# relative_P_1000                   0.6917             0.6917            0.6917
# success_1                         0.5980             0.5879            0.5226
# success_5                         0.8191             0.8342            0.7990
# success_10                        0.9045             0.8995            0.8744
# set_P                             0.0542             0.0542            0.0542
# set_relative_P                    0.6933             0.6933            0.6933
# set_recall                        0.6917             0.6917            0.6917
# set_map                           0.0389             0.0389            0.0389
# set_F                             0.0864             0.0864            0.0864
# num_nonrel_judged_ret         70857.0000         70857.0000        70857.0000
#
#                        QL_[1000_0.45_100]  QL_[1000_0.45_200]  \
# index
# num_q                            199.0000            199.0000
# num_ret                       192035.0000         192035.0000
# num_rel                        13369.0000          13369.0000
# num_rel_ret                     7909.0000           7909.0000
# map                                0.2556              0.2562
# gm_map                             0.1514              0.1510
# Rprec                              0.2978              0.3000
# bpref                              0.2638              0.2638
# recip_rank                         0.7155              0.7130
# iprec_at_recall_0.00               0.7587              0.7531
# iprec_at_recall_0.10               0.5352              0.5369
# iprec_at_recall_0.20               0.4222              0.4284
# iprec_at_recall_0.30               0.3420              0.3447
# iprec_at_recall_0.40               0.2699              0.2724
# iprec_at_recall_0.50               0.2290              0.2303
# iprec_at_recall_0.60               0.1822              0.1818
# iprec_at_recall_0.70               0.1404              0.1391
# iprec_at_recall_0.80               0.0948              0.0943
# iprec_at_recall_0.90               0.0624              0.0624
# iprec_at_recall_1.00               0.0307              0.0303
# P_5                                0.4794              0.4925
# P_10                               0.4332              0.4402
# P_15                               0.3903              0.3933
# P_20                               0.3590              0.3656
# P_30                               0.3151              0.3176
# P_100                              0.1851              0.1849
# P_200                              0.1255              0.1255
# P_500                              0.0680              0.0678
# P_1000                             0.0397              0.0397
# recall_5                           0.0908              0.0934
# ...                                   ...                 ...
# ndcg_cut_200                       0.4503              0.4513
# ndcg_cut_500                       0.5002              0.4998
# ndcg_cut_1000                      0.5268              0.5272
# map_cut_5                          0.0750              0.0761
# map_cut_10                         0.1108              0.1116
# map_cut_15                         0.1318              0.1330
# map_cut_20                         0.1470              0.1487
# map_cut_30                         0.1688              0.1696
# map_cut_100                        0.2190              0.2197
# map_cut_200                        0.2375              0.2383
# map_cut_500                        0.2507              0.2512
# map_cut_1000                       0.2556              0.2562
# relative_P_5                       0.4812              0.4942
# relative_P_10                      0.4491              0.4558
# relative_P_15                      0.4217              0.4245
# relative_P_20                      0.4070              0.4138
# relative_P_30                      0.3996              0.4023
# relative_P_100                     0.4417              0.4404
# relative_P_200                     0.5172              0.5188
# relative_P_500                     0.6288              0.6272
# relative_P_1000                    0.6917              0.6917
# success_1                          0.6181              0.6030
# success_5                          0.8392              0.8492
# success_10                         0.8995              0.9095
# set_P                              0.0542              0.0542
# set_relative_P                     0.6933              0.6933
# set_recall                         0.6917              0.6917
# set_map                            0.0389              0.0389
# set_F                              0.0864              0.0864
# num_nonrel_judged_ret          70857.0000          70857.0000
#
#                        QL_[1000_0.45_50]  QL_[1000_0.6_100]  \
# index
# num_q                           199.0000           199.0000
# num_ret                      192035.0000        192035.0000
# num_rel                       13369.0000         13369.0000
# num_rel_ret                    7909.0000          7909.0000
# map                               0.2532             0.2590
# gm_map                            0.1505             0.1525
# Rprec                             0.2981             0.3034
# bpref                             0.2628             0.2666
# recip_rank                        0.7022             0.7154
# iprec_at_recall_0.00              0.7491             0.7538
# iprec_at_recall_0.10              0.5326             0.5446
# iprec_at_recall_0.20              0.4160             0.4280
# iprec_at_recall_0.30              0.3333             0.3454
# iprec_at_recall_0.40              0.2654             0.2753
# iprec_at_recall_0.50              0.2276             0.2332
# iprec_at_recall_0.60              0.1831             0.1846
# iprec_at_recall_0.70              0.1424             0.1408
# iprec_at_recall_0.80              0.0957             0.0955
# iprec_at_recall_0.90              0.0644             0.0651
# iprec_at_recall_1.00              0.0313             0.0331
# P_5                               0.4714             0.4975
# P_10                              0.4241             0.4367
# P_15                              0.3863             0.3963
# P_20                              0.3548             0.3633
# P_30                              0.3092             0.3142
# P_100                             0.1845             0.1858
# P_200                             0.1253             0.1260
# P_500                             0.0680             0.0680
# P_1000                            0.0397             0.0397
# recall_5                          0.0895             0.0949
# ...                                  ...                ...
# ndcg_cut_200                      0.4475             0.4536
# ndcg_cut_500                      0.4986             0.5025
# ndcg_cut_1000                     0.5246             0.5290
# map_cut_5                         0.0734             0.0790
# map_cut_10                        0.1089             0.1135
# map_cut_15                        0.1290             0.1357
# map_cut_20                        0.1455             0.1497
# map_cut_30                        0.1662             0.1712
# map_cut_100                       0.2165             0.2225
# map_cut_200                       0.2351             0.2411
# map_cut_500                       0.2483             0.2541
# map_cut_1000                      0.2532             0.2590
# relative_P_5                      0.4731             0.4992
# relative_P_10                     0.4401             0.4522
# relative_P_15                     0.4183             0.4282
# relative_P_20                     0.4046             0.4114
# relative_P_30                     0.3934             0.3994
# relative_P_100                    0.4388             0.4445
# relative_P_200                    0.5148             0.5199
# relative_P_500                    0.6311             0.6300
# relative_P_1000                   0.6917             0.6917
# success_1                         0.5980             0.6030
# success_5                         0.8392             0.8492
# success_10                        0.9045             0.8945
# set_P                             0.0542             0.0542
# set_relative_P                    0.6933             0.6933
# set_recall                        0.6917             0.6917
# set_map                           0.0389             0.0389
# set_F                             0.0864             0.0864
# num_nonrel_judged_ret         70857.0000         70857.0000
#
#                        QL_[1000_0.6_200]  QL_[1000_0.6_50]  \
# index
# num_q                           199.0000          199.0000
# num_ret                      192035.0000       192035.0000
# num_rel                       13369.0000        13369.0000
# num_rel_ret                    7909.0000         7909.0000
# map                               0.2577            0.2586
# gm_map                            0.1509            0.1529
# Rprec                             0.3024            0.3032
# bpref                             0.2656            0.2664
# recip_rank                        0.7038            0.7106
# iprec_at_recall_0.00              0.7484            0.7500
# iprec_at_recall_0.10              0.5418            0.5464
# iprec_at_recall_0.20              0.4306            0.4245
# iprec_at_recall_0.30              0.3451            0.3447
# iprec_at_recall_0.40              0.2744            0.2751
# iprec_at_recall_0.50              0.2313            0.2326
# iprec_at_recall_0.60              0.1845            0.1843
# iprec_at_recall_0.70              0.1394            0.1425
# iprec_at_recall_0.80              0.0946            0.0973
# iprec_at_recall_0.90              0.0651            0.0663
# iprec_at_recall_1.00              0.0327            0.0334
# P_5                               0.4965            0.4935
# P_10                              0.4332            0.4402
# P_15                              0.3936            0.3950
# P_20                              0.3626            0.3611
# P_30                              0.3154            0.3151
# P_100                             0.1850            0.1859
# P_200                             0.1257            0.1262
# P_500                             0.0680            0.0684
# P_1000                            0.0397            0.0397
# recall_5                          0.0957            0.0932
# ...                                  ...               ...
# ndcg_cut_200                      0.4518            0.4531
# ndcg_cut_500                      0.5003            0.5037
# ndcg_cut_1000                     0.5273            0.5286
# map_cut_5                         0.0783            0.0769
# map_cut_10                        0.1126            0.1128
# map_cut_15                        0.1345            0.1338
# map_cut_20                        0.1497            0.1493
# map_cut_30                        0.1707            0.1705
# map_cut_100                       0.2212            0.2218
# map_cut_200                       0.2398            0.2406
# map_cut_500                       0.2528            0.2540
# map_cut_1000                      0.2577            0.2586
# relative_P_5                      0.4982            0.4952
# relative_P_10                     0.4487            0.4558
# relative_P_15                     0.4254            0.4263
# relative_P_20                     0.4116            0.4088
# relative_P_30                     0.3988            0.3997
# relative_P_100                    0.4442            0.4447
# relative_P_200                    0.5202            0.5201
# relative_P_500                    0.6284            0.6341
# relative_P_1000                   0.6917            0.6917
# success_1                         0.5829            0.6080
# success_5                         0.8543            0.8492
# success_10                        0.8945            0.8995
# set_P                             0.0542            0.0542
# set_relative_P                    0.6933            0.6933
# set_recall                        0.6917            0.6917
# set_map                           0.0389            0.0389
# set_F                             0.0864            0.0864
# num_nonrel_judged_ret         70857.0000        70857.0000
#
#                        QL_[1000_0.75_100]        ...         QL_[750_0.3_50]  \
# index                                            ...
# num_q                            199.0000        ...                199.0000
# num_ret                       192035.0000        ...             192035.0000
# num_rel                        13369.0000        ...              13369.0000
# num_rel_ret                     7909.0000        ...               7909.0000
# map                                0.2591        ...                  0.2313
# gm_map                             0.1514        ...                  0.1318
# Rprec                              0.3017        ...                  0.2758
# bpref                              0.2664        ...                  0.2447
# recip_rank                         0.7071        ...                  0.6469
# iprec_at_recall_0.00               0.7538        ...                  0.6921
# iprec_at_recall_0.10               0.5464        ...                  0.4838
# iprec_at_recall_0.20               0.4315        ...                  0.3733
# iprec_at_recall_0.30               0.3465        ...                  0.3031
# iprec_at_recall_0.40               0.2775        ...                  0.2526
# iprec_at_recall_0.50               0.2342        ...                  0.2135
# iprec_at_recall_0.60               0.1824        ...                  0.1708
# iprec_at_recall_0.70               0.1394        ...                  0.1320
# iprec_at_recall_0.80               0.0944        ...                  0.0847
# iprec_at_recall_0.90               0.0656        ...                  0.0531
# iprec_at_recall_1.00               0.0343        ...                  0.0206
# P_5                                0.4925        ...                  0.4281
# P_10                               0.4337        ...                  0.3759
# P_15                               0.3940        ...                  0.3514
# P_20                               0.3646        ...                  0.3314
# P_30                               0.3127        ...                  0.2920
# P_100                              0.1849        ...                  0.1761
# P_200                              0.1256        ...                  0.1197
# P_500                              0.0677        ...                  0.0660
# P_1000                             0.0397        ...                  0.0397
# recall_5                           0.0938        ...                  0.0801
# ...                                   ...        ...                     ...
# ndcg_cut_200                       0.4533        ...                  0.4208
# ndcg_cut_500                       0.5011        ...                  0.4735
# ndcg_cut_1000                      0.5287        ...                  0.5060
# map_cut_5                          0.0791        ...                  0.0656
# map_cut_10                         0.1142        ...                  0.0943
# map_cut_15                         0.1359        ...                  0.1143
# map_cut_20                         0.1515        ...                  0.1297
# map_cut_30                         0.1717        ...                  0.1490
# map_cut_100                        0.2227        ...                  0.1955
# map_cut_200                        0.2411        ...                  0.2126
# map_cut_500                        0.2542        ...                  0.2257
# map_cut_1000                       0.2591        ...                  0.2313
# relative_P_5                       0.4940        ...                  0.4294
# relative_P_10                      0.4494        ...                  0.3898
# relative_P_15                      0.4258        ...                  0.3799
# relative_P_20                      0.4133        ...                  0.3781
# relative_P_30                      0.3967        ...                  0.3727
# relative_P_100                     0.4443        ...                  0.4201
# relative_P_200                     0.5211        ...                  0.4930
# relative_P_500                     0.6284        ...                  0.6126
# relative_P_1000                    0.6917        ...                  0.6917
# success_1                          0.5980        ...                  0.5327
# success_5                          0.8492        ...                  0.7940
# success_10                         0.8945        ...                  0.8643
# set_P                              0.0542        ...                  0.0542
# set_relative_P                     0.6933        ...                  0.6933
# set_recall                         0.6917        ...                  0.6917
# set_map                            0.0389        ...                  0.0389
# set_F                              0.0864        ...                  0.0864
# num_nonrel_judged_ret          70857.0000        ...              70857.0000
#
#                        QL_[750_0.45_100]  QL_[750_0.45_200]  QL_[750_0.45_50]  \
# index
# num_q                           199.0000           199.0000          199.0000
# num_ret                      192035.0000        192035.0000       192035.0000
# num_rel                       13369.0000         13369.0000        13369.0000
# num_rel_ret                    7909.0000          7909.0000         7909.0000
# map                               0.2538             0.2536            0.2518
# gm_map                            0.1486             0.1479            0.1479
# Rprec                             0.2964             0.2960            0.2968
# bpref                             0.2618             0.2610            0.2620
# recip_rank                        0.7101             0.7039            0.6813
# iprec_at_recall_0.00              0.7525             0.7456            0.7266
# iprec_at_recall_0.10              0.5301             0.5316            0.5267
# iprec_at_recall_0.20              0.4211             0.4257            0.4151
# iprec_at_recall_0.30              0.3423             0.3425            0.3336
# iprec_at_recall_0.40              0.2661             0.2669            0.2666
# iprec_at_recall_0.50              0.2279             0.2272            0.2284
# iprec_at_recall_0.60              0.1797             0.1789            0.1822
# iprec_at_recall_0.70              0.1401             0.1387            0.1414
# iprec_at_recall_0.80              0.0950             0.0942            0.0943
# iprec_at_recall_0.90              0.0611             0.0609            0.0634
# iprec_at_recall_1.00              0.0299             0.0296            0.0298
# P_5                               0.4814             0.4935            0.4714
# P_10                              0.4322             0.4367            0.4246
# P_15                              0.3899             0.3930            0.3889
# P_20                              0.3565             0.3590            0.3520
# P_30                              0.3154             0.3164            0.3124
# P_100                             0.1847             0.1843            0.1848
# P_200                             0.1247             0.1239            0.1245
# P_500                             0.0677             0.0673            0.0677
# P_1000                            0.0397             0.0397            0.0397
# recall_5                          0.0881             0.0936            0.0901
# ...                                  ...                ...               ...
# ndcg_cut_200                      0.4467             0.4467            0.4439
# ndcg_cut_500                      0.4970             0.4954            0.4953
# ndcg_cut_1000                     0.5247             0.5249            0.5224
# map_cut_5                         0.0735             0.0762            0.0734
# map_cut_10                        0.1104             0.1105            0.1083
# map_cut_15                        0.1319             0.1325            0.1292
# map_cut_20                        0.1464             0.1472            0.1447
# map_cut_30                        0.1677             0.1685            0.1660
# map_cut_100                       0.2178             0.2179            0.2157
# map_cut_200                       0.2358             0.2353            0.2337
# map_cut_500                       0.2488             0.2485            0.2468
# map_cut_1000                      0.2538             0.2536            0.2518
# relative_P_5                      0.4829             0.4952            0.4731
# relative_P_10                     0.4481             0.4525            0.4406
# relative_P_15                     0.4209             0.4247            0.4198
# relative_P_20                     0.4054             0.4081            0.4018
# relative_P_30                     0.3994             0.4016            0.3963
# relative_P_100                    0.4399             0.4391            0.4392
# relative_P_200                    0.5118             0.5123            0.5112
# relative_P_500                    0.6251             0.6201            0.6279
# relative_P_1000                   0.6917             0.6917            0.6917
# success_1                         0.6131             0.5980            0.5628
# success_5                         0.8342             0.8492            0.8392
# success_10                        0.8995             0.9095            0.9095
# set_P                             0.0542             0.0542            0.0542
# set_relative_P                    0.6933             0.6933            0.6933
# set_recall                        0.6917             0.6917            0.6917
# set_map                           0.0389             0.0389            0.0389
# set_F                             0.0864             0.0864            0.0864
# num_nonrel_judged_ret         70857.0000         70857.0000        70857.0000
#
#                        QL_[750_0.6_100]  QL_[750_0.6_200]  QL_[750_0.6_50]  \
# index
# num_q                          199.0000          199.0000         199.0000
# num_ret                     192035.0000       192035.0000      192035.0000
# num_rel                      13369.0000        13369.0000       13369.0000
# num_rel_ret                   7909.0000         7909.0000        7909.0000
# map                              0.2580            0.2568           0.2583
# gm_map                           0.1511            0.1497           0.1519
# Rprec                            0.3034            0.3007           0.3027
# bpref                            0.2661            0.2647           0.2667
# recip_rank                       0.7121            0.7009           0.7047
# iprec_at_recall_0.00             0.7540            0.7442           0.7481
# iprec_at_recall_0.10             0.5410            0.5360           0.5398
# iprec_at_recall_0.20             0.4305            0.4281           0.4266
# iprec_at_recall_0.30             0.3426            0.3431           0.3444
# iprec_at_recall_0.40             0.2751            0.2724           0.2741
# iprec_at_recall_0.50             0.2331            0.2304           0.2320
# iprec_at_recall_0.60             0.1830            0.1821           0.1832
# iprec_at_recall_0.70             0.1409            0.1394           0.1420
# iprec_at_recall_0.80             0.0965            0.0952           0.0972
# iprec_at_recall_0.90             0.0652            0.0645           0.0668
# iprec_at_recall_1.00             0.0329            0.0324           0.0331
# P_5                              0.4874            0.4965           0.4955
# P_10                             0.4392            0.4342           0.4422
# P_15                             0.3903            0.3930           0.3923
# P_20                             0.3626            0.3611           0.3593
# P_30                             0.3178            0.3142           0.3181
# P_100                            0.1844            0.1842           0.1854
# P_200                            0.1257            0.1249           0.1257
# P_500                            0.0679            0.0676           0.0684
# P_1000                           0.0397            0.0397           0.0397
# recall_5                         0.0930            0.0944           0.0936
# ...                                 ...               ...              ...
# ndcg_cut_200                     0.4523            0.4505           0.4525
# ndcg_cut_500                     0.5011            0.4986           0.5029
# ndcg_cut_1000                    0.5281            0.5268           0.5283
# map_cut_5                        0.0775            0.0782           0.0769
# map_cut_10                       0.1144            0.1133           0.1137
# map_cut_15                       0.1346            0.1347           0.1337
# map_cut_20                       0.1494            0.1497           0.1489
# map_cut_30                       0.1718            0.1705           0.1715
# map_cut_100                      0.2213            0.2204           0.2217
# map_cut_200                      0.2401            0.2388           0.2403
# map_cut_500                      0.2531            0.2518           0.2536
# map_cut_1000                     0.2580            0.2568           0.2583
# relative_P_5                     0.4892            0.4982           0.4972
# relative_P_10                    0.4551            0.4503           0.4581
# relative_P_15                    0.4224            0.4252           0.4235
# relative_P_20                    0.4109            0.4101           0.4073
# relative_P_30                    0.4022            0.3981           0.4030
# relative_P_100                   0.4406            0.4397           0.4420
# relative_P_200                   0.5197            0.5181           0.5198
# relative_P_500                   0.6279            0.6246           0.6321
# relative_P_1000                  0.6917            0.6917           0.6917
# success_1                        0.6030            0.5829           0.5980
# success_5                        0.8442            0.8492           0.8543
# success_10                       0.8995            0.8995           0.8995
# set_P                            0.0542            0.0542           0.0542
# set_relative_P                   0.6933            0.6933           0.6933
# set_recall                       0.6917            0.6917           0.6917
# set_map                          0.0389            0.0389           0.0389
# set_F                            0.0864            0.0864           0.0864
# num_nonrel_judged_ret        70857.0000        70857.0000       70857.0000
#
#                        QL_[750_0.75_100]  QL_[750_0.75_200]  QL_[750_0.75_50]
# index
# num_q                           199.0000           199.0000          199.0000
# num_ret                      192035.0000        192035.0000       192035.0000
# num_rel                       13369.0000         13369.0000        13369.0000
# num_rel_ret                    7909.0000          7909.0000         7909.0000
# map                               0.2578             0.2572            0.2587
# gm_map                            0.1497             0.1489            0.1508
# Rprec                             0.3013             0.3012            0.3027
# bpref                             0.2658             0.2650            0.2669
# recip_rank                        0.7107             0.7065            0.7020
# iprec_at_recall_0.00              0.7517             0.7472            0.7446
# iprec_at_recall_0.10              0.5396             0.5372            0.5434
# iprec_at_recall_0.20              0.4286             0.4300            0.4297
# iprec_at_recall_0.30              0.3439             0.3435            0.3454
# iprec_at_recall_0.40              0.2768             0.2747            0.2766
# iprec_at_recall_0.50              0.2313             0.2289            0.2325
# iprec_at_recall_0.60              0.1826             0.1817            0.1843
# iprec_at_recall_0.70              0.1410             0.1402            0.1410
# iprec_at_recall_0.80              0.0943             0.0942            0.0960
# iprec_at_recall_0.90              0.0658             0.0653            0.0664
# iprec_at_recall_1.00              0.0342             0.0341            0.0346
# P_5                               0.4894             0.4874            0.4915
# P_10                              0.4327             0.4322            0.4332
# P_15                              0.3943             0.3936            0.3930
# P_20                              0.3606             0.3608            0.3616
# P_30                              0.3126             0.3099            0.3141
# P_100                             0.1841             0.1838            0.1843
# P_200                             0.1255             0.1251            0.1259
# P_500                             0.0678             0.0677            0.0681
# P_1000                            0.0397             0.0397            0.0397
# recall_5                          0.0941             0.0947            0.0956
# ...                                  ...                ...               ...
# ndcg_cut_200                      0.4520             0.4508            0.4524
# ndcg_cut_500                      0.5002             0.4991            0.5013
# ndcg_cut_1000                     0.5275             0.5269            0.5280
# map_cut_5                         0.0783             0.0788            0.0791
# map_cut_10                        0.1133             0.1135            0.1132
# map_cut_15                        0.1358             0.1356            0.1350
# map_cut_20                        0.1500             0.1502            0.1500
# map_cut_30                        0.1704             0.1698            0.1710
# map_cut_100                       0.2213             0.2208            0.2218
# map_cut_200                       0.2399             0.2392            0.2407
# map_cut_500                       0.2529             0.2523            0.2539
# map_cut_1000                      0.2578             0.2572            0.2587
# relative_P_5                      0.4912             0.4892            0.4932
# relative_P_10                     0.4482             0.4479            0.4487
# relative_P_15                     0.4267             0.4258            0.4248
# relative_P_20                     0.4090             0.4094            0.4100
# relative_P_30                     0.3952             0.3925            0.3971
# relative_P_100                    0.4423             0.4408            0.4415
# relative_P_200                    0.5205             0.5188            0.5206
# relative_P_500                    0.6272             0.6255            0.6287
# relative_P_1000                   0.6917             0.6917            0.6917
# success_1                         0.6030             0.5980            0.5829
# success_5                         0.8392             0.8392            0.8442
# success_10                        0.8995             0.8995            0.8995
# set_P                             0.0542             0.0542            0.0542
# set_relative_P                    0.6933             0.6933            0.6933
# set_recall                        0.6917             0.6917            0.6917
# set_map                           0.0389             0.0389            0.0389
# set_F                             0.0864             0.0864            0.0864
# num_nonrel_judged_ret         70857.0000         70857.0000        70857.0000
#
# [93 rows x 60 columns]

# %% [markdown]
# Best Parameter on Each Cross Validation Training Fold

# %%
resultQL.loc['ndcg_cut_10'].idxmax(axis=1)
# Out:
# 'QL_[1000_0.45_200]'

# %%
# Out:
# {1: array([  1,  18,  20,  25,  29,  34,  42,  45,  59,  67,  70,  75,  82,
#          89,  92, 100, 106, 117, 121, 122, 124, 126, 129, 132, 136, 139,
#         146, 152, 153, 161, 162, 179, 186, 188, 189, 191, 192, 204, 208,
#         209, 212, 213, 214, 218, 221, 222, 238, 242, 247, 249]),
#  2: array([  2,   6,  11,  13,  16,  22,  31,  35,  39,  41,  49,  50,  53,
#          58,  62,  69,  77,  78,  84,  87,  97,  99, 104, 114, 123, 125,
#         128, 131, 147, 148, 155, 156, 157, 159, 165, 171, 172, 173, 178,
#         190, 197, 198, 210, 227, 228, 231, 235, 237, 239, 248]),
#  3: array([  5,   7,  12,  19,  21,  23,  24,  28,  32,  33,  48,  55,  56,
#          57,  60,  85,  96, 101, 107, 109, 111, 113, 115, 116, 119, 133,
#         134, 135, 143, 150, 151, 158, 169, 170, 177, 183, 184, 185, 187,
#         200, 206, 207, 215, 216, 217, 223, 225, 226, 233, 236]),
#  4: array([  9,  10,  27,  36,  40,  46,  47,  54,  63,  64,  66,  71,  72,
#          73,  80,  83,  88,  93,  94,  95, 102, 103, 105, 108, 110, 112,
#         127, 130, 137, 140, 141, 142, 154, 164, 166, 168, 174, 181, 195,
#         199, 203, 211, 219, 229, 230, 234, 240, 241, 244, 246]),
#  5: array([  0,   3,   4,   8,  14,  15,  17,  26,  30,  37,  38,  43,  44,
#          51,  52,  61,  65,  68,  74,  76,  79,  81,  86,  90,  91,  98,
#         118, 120, 138, 144, 145, 149, 160, 163, 167, 175, 176, 180, 182,
#         193, 194, 196, 201, 202, 205, 220, 224, 232, 243, 245])}

# %% [markdown]
# ## Testing on each cross validation test fold with the respective best parameter from the training fold

# %%
# queryTestindex[cv]= test_index
cv =5
X_test = queryDF.loc[queryTestindex[cv]].reset_index()
for expansion_terms in [ 200]:
    for lamda in [ 0.45]: 
        startTime = time.time()
#             queryTrainFile = originalGlobal(expansion_terms, lamda, X_train, 'train', cv)

        queryTestFile = originalGlobal(expansion_terms, lamda, X_test, 'test', cv)
        endTime = time.time()
        t_sec = round(endTime - startTime)
        (t_min, t_sec) = divmod(t_sec,60)
        print('Query File for Lamda {} and expansion terms {} created, time taken {} minutes and {} seconds'.format(lamda, expansion_terms, t_min, t_sec))
        for mu in [ 1000]:
            startTime = time.time()
            outputFile = 'QL_['+str(mu)+'_'+str(lamda)+'_'+str(expansion_terms)+'_'+str(cv) + '].indri'
            command_input= r'"C:\Users\nroy0\Downloads\Thesis\Lemur\bin\IndriRunQuery.exe" '+str(queryTestFile)+' -index=Vol45/index -count=1000 -trecFormat=true -queryOffset=-1 -rule=method:dirichlet,mu:' +str(mu)+' -stemmer.name=krovetz > C:/Users/nroy0/Downloads/Thesis/trec_eval.9.0/original/global100/test/'+str(outputFile) 
            args = shlex.split(command_input)
            p = subprocess.run(args, stderr=subprocess.STDOUT,shell=True)
            endTime = time.time()
            t_sec = round(endTime - startTime)
            (t_min, t_sec) = divmod(t_sec,60)
            print("Mu {} complete, time take {} min and {} sec".format(mu, t_min, t_sec ))
# Out:
# Query File for Lamda 0.45 and expansion terms 200 created, time taken 2 minutes and 10 seconds
# Mu 1000 complete, time take 0 min and 22 sec

# %%
path = r'C:\Users\nroy0\Downloads\Thesis\trec_eval.9.0\original\global100\test'
filenames = glob.glob(path + "/*.csv")
dfs = []
count = 0
for filename in filenames:
    match = re.search(r'\w\w\_\[\d\.?\d*\_\d\.?\d*\_\d+\_\d+\]', filename)
    count = count + 1
#     print(count)
    colname = match.group()
    df = pd.read_table(filename,sep='\t', index_col=None, header=None, usecols=[2], skiprows =1, names =  [colname] , quoting=csv.QUOTE_NONE)
    dfs.append(df)
resultQLTest = pd.concat(dfs, axis=1, ignore_index = False)

resultQLTest['index']=[ 'num_q',
'num_ret',
'num_rel',
'num_rel_ret',
'map',
'gm_map',
'Rprec',
'bpref',
'recip_rank',
'iprec_at_recall_0.00',
'iprec_at_recall_0.10',
'iprec_at_recall_0.20',
'iprec_at_recall_0.30',
'iprec_at_recall_0.40',
'iprec_at_recall_0.50',
'iprec_at_recall_0.60',
'iprec_at_recall_0.70',
'iprec_at_recall_0.80',
'iprec_at_recall_0.90',
'iprec_at_recall_1.00',
'P_5',
'P_10',
'P_15',
'P_20',
'P_30',
'P_100',
'P_200',
'P_500',
'P_1000',
'recall_5',
'recall_10',
'recall_15',
'recall_20',
'recall_30',
'recall_100',
'recall_200',
'recall_500',
'recall_1000',
'infAP',
'gm_bpref',
'Rprec_mult_0.20',
'Rprec_mult_0.40',
'Rprec_mult_0.60',
'Rprec_mult_0.80',
'Rprec_mult_1.00',
'Rprec_mult_1.20',
'Rprec_mult_1.40',
'Rprec_mult_1.60',
'Rprec_mult_1.80',
'Rprec_mult_2.00',
'utility',
'11pt_avg',
'binG',
'G',
'ndcg',
'ndcg_rel',
'Rndcg',
'ndcg_cut_5',
'ndcg_cut_10',
'ndcg_cut_15',
'ndcg_cut_20',
'ndcg_cut_30',
'ndcg_cut_100',
'ndcg_cut_200',
'ndcg_cut_500',
'ndcg_cut_1000',
'map_cut_5',
'map_cut_10',
'map_cut_15',
'map_cut_20',
'map_cut_30',
'map_cut_100',
'map_cut_200',
'map_cut_500',
'map_cut_1000',
'relative_P_5',
'relative_P_10',
'relative_P_15',
'relative_P_20',
'relative_P_30',
'relative_P_100',
'relative_P_200',
'relative_P_500',
'relative_P_1000',
'success_1',
'success_5',
'success_10',
'set_P',
'set_relative_P',
'set_recall',
'set_map',
'set_F',
'num_nonrel_judged_ret']
resultQLTest = resultQLTest.set_index('index')
# resultQLTest['ndcg_cut_10']

# %% [markdown]
# ## Average of the 5-fold cross Validation Test Metric

# %%
np.mean((resultQLTest.loc['ndcg_cut_10']))
# Out:
# 0.45021999999999995
